# %%
# !pip install requests
# !pip install matplotlib

# %%
import requests

import time

data_points = []

for _ in range(100):
    response = requests.get("http://api.open-notify.org/iss-now.json")
    data = response.json()
    
    latitude = float(data["iss_position"]["latitude"])
    longitude = float(data["iss_position"]["longitude"])
    timestamp = data["timestamp"]
    
    data_points.append({
        "latitude": latitude,
        "longitude": longitude,
        "timestamp": timestamp
    })
    
    time.sleep(10)

for data_point in data_points:
    print("Latitude:", data_point["latitude"])
    print("Longitude:", data_point["longitude"])
    print("Timestamp:", data_point["timestamp"])
    print("-" * 20)
# Out:
# Latitude: 41.7416
# Longitude: 30.7104
# Timestamp: 1689294777
# --------------------
# Latitude: 41.3618
# Longitude: 31.4201
# Timestamp: 1689294788
# --------------------
# Latitude: 40.9955
# Longitude: 32.0878
# Timestamp: 1689294798
# --------------------
# Latitude: 40.6062
# Longitude: 32.7805
# Timestamp: 1689294808
# --------------------
# Latitude: 40.2124
# Longitude: 33.4645
# Timestamp: 1689294819
# --------------------
# Latitude: 39.814
# Longitude: 34.1401
# Timestamp: 1689294829
# --------------------
# Latitude: 39.4305
# Longitude: 34.7757
# Timestamp: 1689294839
# --------------------
# Latitude: 39.0236
# Longitude: 35.4351
# Timestamp: 1689294850
# --------------------
# Latitude: 38.6125
# Longitude: 36.0865
# Timestamp: 1689294860
# --------------------
# Latitude: 38.2172
# Longitude: 36.6995
# Timestamp: 1689294870
# --------------------
# Latitude: 37.7982
# Longitude: 37.3353
# Timestamp: 1689294881
# --------------------
# Latitude: 37.3755
# ...

# %%
import matplotlib.pyplot as plt

latitude = [data_point["latitude"] for data_point in data_points]
longitude = [data_point["longitude"] for data_point in data_points]

plt.figure(figsize=(40, 10))
plt.plot(longitude, latitude, '-o')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Path of the International Space Station')
plt.grid(True)
plt.show()
